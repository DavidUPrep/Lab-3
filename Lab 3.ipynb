# %% [markdown]
# # Lab 3 - Analysis of Nuclear and Alternative Energy use as a Percentage of Total Energy Consumption by Country using Pandas
# ## David Abramowitz 10/17/2018

# %% [markdown]
# ## Abstract

# %% [markdown]
# In this lab, I looked at data from the World Bank on countries' percentage of nuclear and alternative energy use compared to their total energy use. The countries with energy percentages at or above the 75th percentile for 2010 (2010 being an arbitrary choice) were found. This means that if from 1960-2017 a country had a percentage above the 75th percentile for 2010 then that country was listed.

# %% [markdown]
# ## Dataset Preparation

# %% [markdown]
# This data was accessed through the World Bank website, which can be found here: https://data.worldbank.org/indicator/EG.USE.COMM.CL.ZS?view=chart. The data itself came from the International Energy Agency and the Organization for Economic Cooperation and Development. Here is the original CSV file: API_EG.USE.COMM.CL.ZS_DS2_en_csv_v2_10082393.csv. This data represents the percentage of nuclear and alternative energy use. So, if half of a country's energy production came from a nuclear or alternative source then its percentaeg would be 50. Note that this figure does not take into consideration the volume of energy production. For example, if the country with half of its energy coming form nuclear or alternative sources is Country A and a country with a quarter of its energy coming from those sources is Country B, then Country A's percentage will be 50 to B's 25. However Country B may produce two times as much energy as A, so while B's percentage is half that of A's, the energy outpute is equal.
#
# Here is a link to data in Google Sheets: https://docs.google.com/spreadsheets/d/1zKy34i5Jsp_heEU76nN3KP3mTYfUguFIKJKJ671mB7k/edit?usp=sharing
# The names in red are those that are suspected to be noncountries, and those in yellow are territories, protectorates, or other areas where confusion may arise. The four rows of hear data are intact as they do not get removed in Google Sheets.

# %% [markdown]
# This dataset included indexes, groups of countries that created several redundancies. Becuase my focus was on indivudal countries, these noncountries had to be removed. Below are all of the names that were removed:
# - Arab World
# - Central Europe and the Baltics
# - Caribbean small states
# - East Asia & Pacific (excluding high income)
# - Early-demographic dividend
# - East Asia & Pacific
# - Europe & Central Asia (excluding high income)
# - Europe & Central Asia
# - Euro area
# - European Union
# - Fragile and conflict affected situations
# - High income
# - Heavily indebted poor countries (HIPC)
# - IBRD only
# - IDA & IBRD total
# - IDA total
# - IDA blend
# - IDA only
# - Not classified
# - Latin America & Caribbean (excluding high income)
# - Latin America & Caribbean
# - Least developed countries: UN classification
# - Low income
# - Lower middle income
# - Low & middle income
# - Late-demographic dividend
# - Middle East & North Africa
# - Middle income
# - Middle East & North Africa (excluding high income)
# - North America
# - OECD members
# - Other small states
# - Pre-demographic dividend
# - Pacific island small states
# - Post-demographic dividend
# - South Asia
# - Sub-Saharan Africa (excluding high income)
# - Sub-Saharan Africa
# - Small states
# - East Asia & Pacific (IDA & IBRD countries)
# - Europe & Central Asia (IDA & IBRD countries)
# - Latin America & the Caribbean (IDA & IBRD countries)
# - Middle East & North Africa (IDA & IBRD countries)
# - South Asia (IDA & IBRD)
# - Sub-Saharan Africa (IDA & IBRD countries)
# - Upper middle income
# - World

# %% [markdown]
# Territories such as Puerto Rico were counted seperately. Below is a list of territories/protectorates and other areas of potential confusion. All of these were counted as being seperate to avoid confusion.
# - American Samoa
# - Channel Islands
# - Hong Kong SAR, China
# - Macao SAR, China
# - New Caledonia
# - Puerto Rico
# - West Bank and Gaza
# - French Polynesia
# - Sint Maarten (Dutch part)
# - Turks and Caicos Islands
# - British Virgin Islands
# - Virgin Islands (U.S.)

# %%
#"ARB", "CEB", "CSS", "EAP", "EAR", "EAS", "ECA", "ECS", "EMU", "EUU", "FCS", "HIC", "HPC", "IBD", "IBT", "IDA", "IDB", "IDX", "INX", "LAC", "LCN", "LDC", "LIC", "LMC", "LMY", "LTE", "MEA", "MIC", "MNA", "NAC", "OED", "OSS", "PRE", "PSS", "PST", "SAS", "SSA", "SSF", "SST", "TEA", "TEC", "TLA", "TMN", "TSA", "TSS", "UMC", "WLD"]

# %%
#include aliased modules
import math as m
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#rename columns
#new_labels = ['country', 'country_code', 'energy_type', 'indicator_code', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974',]
df = pd.read_csv("WB Energy.csv",
                header=4,
                index_col="Country Code") 
df.rename({"Country Name": "CountryName",
                             "Country Code": "CountryCode",
                             "Indicator Name": "EnergyType",
                             "Indicator Code": "EnergyCode"}, axis="columns", inplace=True)
               
             
                

df.count()
df.describe()
# Out:
#             1960       1961       1962       1963       1964       1965  \
# count  46.000000  46.000000  46.000000  46.000000  46.000000  47.000000
# mean    6.325019   6.621013   6.661239   6.678714   6.711287   6.673118
# std     9.403952   9.972293  10.409084  10.197672  10.631389  10.389580
# min     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     0.747459   0.779350   0.794634   1.188996   1.105815   1.052532
# 50%     2.438224   2.426507   2.414388   2.554352   2.425500   2.378129
# 75%     7.791430   7.729834   7.781150   7.206562   7.589616   6.758723
# max    39.336067  41.459945  43.765543  42.719432  44.453340  44.978477
#
#             1966       1967       1968       1969  ...         2008  \
# count  47.000000  47.000000  47.000000  47.000000  ...   185.000000
# mean    6.832427   6.884276   6.856035   7.179678  ...     7.909000
# std    10.264892  10.752521  10.910252  12.047604  ...    11.287070
# min     0.000000   0.000000   0.011587   0.010454  ...     0.000000
# 25%     1.077096   1.113135   1.059938   0.991892  ...     0.795847
# 50%     3.074811   3.054320   3.051865   2.989922  ...     3.913816
# 75%     7.770004   6.854752   6.136488   5.487899  ...    10.722935
# max    41.215241  43.016621  44.438076  42.956023  ...    86.755199
#
#              2009        2010        2011        2012        2013        2014  \
# count  185.000000  186.000000  185.000000  186.000000  186.000000  181.000000
# mean     8.308095    8.780380    8.120134    8.096422    8.405029    9.079236
# std     11.747496   13.406983   11.796809   11.761237   11.649584   13.421235
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.842419    0.998011    0.856777    0.882214    1.028284    0.997148
# 50%      4.020001    4.052566    4.351175    4.276896    4.781447    4.622443
# 75%     10.743917   10.704580   10.057595   10.244656   11.140800   11.954740
# max     87.803505   96.709004   89.725281   89.638477   89.532280   91.984857
#
#             2015  2016  2017
# count  59.000000   0.0   0.0
# mean   15.856171   NaN   NaN
# std    15.700414   NaN   NaN
# min     0.744933   NaN   NaN
# 25%     5.815518   NaN   NaN
# 50%    10.246729   NaN   NaN
# 75%    19.106437   NaN   NaN
# max    88.400735   NaN   NaN
#
# [8 rows x 58 columns]

# %%
df.head(500)
# Out:
#                                                     CountryName  \
# Country Code
# ABW                                                       Aruba
# AFG                                                 Afghanistan
# AGO                                                      Angola
# ALB                                                     Albania
# AND                                                     Andorra
# ARB                                                  Arab World
# ARE                                        United Arab Emirates
# ARG                                                   Argentina
# ARM                                                     Armenia
# ASM                                              American Samoa
# ATG                                         Antigua and Barbuda
# AUS                                                   Australia
# AUT                                                     Austria
# AZE                                                  Azerbaijan
# BDI                                                     Burundi
# BEL                                                     Belgium
# BEN                                                       Benin
# BFA                                                Burkina Faso
# BGD                                                  Bangladesh
# BGR                                                    Bulgaria
# BHR                                                     Bahrain
# BHS                                                Bahamas, The
# BIH                                      Bosnia and Herzegovina
# BLR                                                     Belarus
# BLZ                                                      Belize
# BMU                                                     Bermuda
# BOL                                                     Bolivia
# BRA                                                      Brazil
# BRB                                                    Barbados
# BRN                                           Brunei Darussalam
# ...                                                         ...
# TLA           Latin America & the Caribbean (IDA & IBRD coun...
# TLS                                                 Timor-Leste
# TMN           Middle East & North Africa (IDA & IBRD countries)
# TON                                                       Tonga
# TSA                                     South Asia (IDA & IBRD)
# TSS                   Sub-Saharan Africa (IDA & IBRD countries)
# TTO                                         Trinidad and Tobago
# TUN                                                     Tunisia
# TUR                                                      Turkey
# TUV                                                      Tuvalu
# TZA                                                    Tanzania
# UGA                                                      Uganda
# UKR                                                     Ukraine
# UMC                                         Upper middle income
# URY                                                     Uruguay
# USA                                               United States
# UZB                                                  Uzbekistan
# VCT                              St. Vincent and the Grenadines
# VEN                                               Venezuela, RB
# VGB                                      British Virgin Islands
# VIR                                       Virgin Islands (U.S.)
# VNM                                                     Vietnam
# VUT                                                     Vanuatu
# WLD                                                       World
# WSM                                                       Samoa
# XKX                                                      Kosovo
# YEM                                                 Yemen, Rep.
# ZAF                                                South Africa
# ZMB                                                      Zambia
# ZWE                                                    Zimbabwe
#
#                                                      EnergyType  \
# Country Code
# ABW           Alternative and nuclear energy (% of total ene...
# AFG           Alternative and nuclear energy (% of total ene...
# AGO           Alternative and nuclear energy (% of total ene...
# ALB           Alternative and nuclear energy (% of total ene...
# AND           Alternative and nuclear energy (% of total ene...
# ARB           Alternative and nuclear energy (% of total ene...
# ARE           Alternative and nuclear energy (% of total ene...
# ARG           Alternative and nuclear energy (% of total ene...
# ARM           Alternative and nuclear energy (% of total ene...
# ASM           Alternative and nuclear energy (% of total ene...
# ATG           Alternative and nuclear energy (% of total ene...
# AUS           Alternative and nuclear energy (% of total ene...
# AUT           Alternative and nuclear energy (% of total ene...
# AZE           Alternative and nuclear energy (% of total ene...
# BDI           Alternative and nuclear energy (% of total ene...
# BEL           Alternative and nuclear energy (% of total ene...
# BEN           Alternative and nuclear energy (% of total ene...
# BFA           Alternative and nuclear energy (% of total ene...
# BGD           Alternative and nuclear energy (% of total ene...
# BGR           Alternative and nuclear energy (% of total ene...
# BHR           Alternative and nuclear energy (% of total ene...
# BHS           Alternative and nuclear energy (% of total ene...
# BIH           Alternative and nuclear energy (% of total ene...
# BLR           Alternative and nuclear energy (% of total ene...
# BLZ           Alternative and nuclear energy (% of total ene...
# BMU           Alternative and nuclear energy (% of total ene...
# BOL           Alternative and nuclear energy (% of total ene...
# BRA           Alternative and nuclear energy (% of total ene...
# BRB           Alternative and nuclear energy (% of total ene...
# BRN           Alternative and nuclear energy (% of total ene...
# ...                                                         ...
# TLA           Alternative and nuclear energy (% of total ene...
# TLS           Alternative and nuclear energy (% of total ene...
# TMN           Alternative and nuclear energy (% of total ene...
# TON           Alternative and nuclear energy (% of total ene...
# TSA           Alternative and nuclear energy (% of total ene...
# TSS           Alternative and nuclear energy (% of total ene...
# TTO           Alternative and nuclear energy (% of total ene...
# TUN           Alternative and nuclear energy (% of total ene...
# TUR           Alternative and nuclear energy (% of total ene...
# TUV           Alternative and nuclear energy (% of total ene...
# TZA           Alternative and nuclear energy (% of total ene...
# UGA           Alternative and nuclear energy (% of total ene...
# UKR           Alternative and nuclear energy (% of total ene...
# UMC           Alternative and nuclear energy (% of total ene...
# URY           Alternative and nuclear energy (% of total ene...
# USA           Alternative and nuclear energy (% of total ene...
# UZB           Alternative and nuclear energy (% of total ene...
# VCT           Alternative and nuclear energy (% of total ene...
# VEN           Alternative and nuclear energy (% of total ene...
# VGB           Alternative and nuclear energy (% of total ene...
# VIR           Alternative and nuclear energy (% of total ene...
# VNM           Alternative and nuclear energy (% of total ene...
# VUT           Alternative and nuclear energy (% of total ene...
# WLD           Alternative and nuclear energy (% of total ene...
# WSM           Alternative and nuclear energy (% of total ene...
# XKX           Alternative and nuclear energy (% of total ene...
# YEM           Alternative and nuclear energy (% of total ene...
# ZAF           Alternative and nuclear energy (% of total ene...
# ZMB           Alternative and nuclear energy (% of total ene...
# ZWE           Alternative and nuclear energy (% of total ene...
#
#                      EnergyCode      1960      1961      1962      1963  \
# Country Code
# ABW           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# AFG           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# AGO           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# ALB           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# AND           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# ARB           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# ARE           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# ARG           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# ARM           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# ASM           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# ATG           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# AUS           EG.USE.COMM.CL.ZS  1.092123  1.216693  1.240643  1.578166
# AUT           EG.USE.COMM.CL.ZS  8.964336  8.748101  8.337474  7.468122
# AZE           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BDI           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BEL           EG.USE.COMM.CL.ZS  0.064140  0.068843  0.058123  0.087126
# BEN           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BFA           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BGD           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BGR           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BHR           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BHS           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BIH           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BLR           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BLZ           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BMU           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BOL           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BRA           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BRB           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BRN           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# ...                         ...       ...       ...       ...       ...
# TLA           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# TLS           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# TMN           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# TON           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# TSA           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# TSS           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# TTO           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# TUN           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# TUR           EG.USE.COMM.CL.ZS  0.806109  1.002690  0.815474  1.480681
# TUV           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# TZA           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# UGA           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# UKR           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# UMC           EG.USE.COMM.CL.ZS  0.806109  1.002690  0.815474  1.480681
# URY           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# USA           EG.USE.COMM.CL.ZS  1.261261  1.334758  1.430062  1.365391
# UZB           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# VCT           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# VEN           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# VGB           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# VIR           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# VNM           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# VUT           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# WLD           EG.USE.COMM.CL.ZS  2.727828  2.800560  2.764664  2.773203
# WSM           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# XKX           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# YEM           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# ZAF           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# ZMB           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# ZWE           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
#
#                   1964       1965       1966  ...        2008       2009  \
# Country Code                                  ...
# ABW                NaN        NaN        NaN  ...         NaN        NaN
# AFG                NaN        NaN        NaN  ...         NaN        NaN
# AGO                NaN        NaN        NaN  ...    2.525102   2.293878
# ALB                NaN        NaN        NaN  ...   15.898280  21.173149
# AND                NaN        NaN        NaN  ...         NaN        NaN
# ARB                NaN        NaN        NaN  ...    0.431715   0.427774
# ARE                NaN        NaN        NaN  ...    0.000000   0.000000
# ARG                NaN        NaN        NaN  ...    5.832679   6.677403
# ARM                NaN        NaN        NaN  ...   26.499591  31.568562
# ASM                NaN        NaN        NaN  ...         NaN        NaN
# ATG                NaN        NaN        NaN  ...         NaN        NaN
# AUS           1.572712   1.808353   1.470217  ...    1.152984   1.223162
# AUT           8.157981  10.023982  10.519054  ...   10.795518  12.145188
# AZE                NaN        NaN        NaN  ...    1.440744   1.664222
# BDI                NaN        NaN        NaN  ...         NaN        NaN
# BEL           0.081804   0.079324   0.093829  ...   20.503938  22.189911
# BEN                NaN        NaN        NaN  ...    0.000000   0.000000
# BFA                NaN        NaN        NaN  ...         NaN        NaN
# BGD                NaN        NaN        NaN  ...    0.305075   0.127287
# BGR                NaN        NaN        NaN  ...   22.251015  24.851118
# BHR                NaN        NaN        NaN  ...    0.000000   0.000000
# BHS                NaN        NaN        NaN  ...         NaN        NaN
# BIH                NaN        NaN        NaN  ...    7.021041   8.629780
# BLR                NaN        NaN        NaN  ...    0.012313   0.014590
# BLZ                NaN        NaN        NaN  ...         NaN        NaN
# BMU                NaN        NaN        NaN  ...         NaN        NaN
# BOL                NaN        NaN        NaN  ...    3.527998   3.367883
# BRA                NaN        NaN        NaN  ...   14.372337  15.561479
# BRB                NaN        NaN        NaN  ...         NaN        NaN
# BRN                NaN        NaN        NaN  ...    0.000000   0.000000
# ...                ...        ...        ...  ...         ...        ...
# TLA                NaN        NaN        NaN  ...    9.877785  10.066878
# TLS                NaN        NaN        NaN  ...         NaN        NaN
# TMN                NaN        NaN        NaN  ...    0.614520   0.629348
# TON                NaN        NaN        NaN  ...         NaN        NaN
# TSA                NaN        NaN        NaN  ...    2.573298   2.548723
# TSS                NaN        NaN        NaN  ...    2.381772   2.452407
# TTO                NaN        NaN        NaN  ...    0.000000   0.000000
# TUN                NaN        NaN        NaN  ...    0.062947   0.165279
# TUR           1.105815   1.409250   1.373221  ...    4.563276   5.392985
# TUV                NaN        NaN        NaN  ...         NaN        NaN
# TZA                NaN        NaN        NaN  ...    1.192854   1.157195
# UGA                NaN        NaN        NaN  ...         NaN        NaN
# UKR                NaN        NaN        NaN  ...   18.240893  19.900961
# UMC           1.105815   1.409250   1.373221  ...    4.952265   5.040086
# URY                NaN        NaN        NaN  ...    9.324447  11.040244
# USA           1.400595   1.472228   1.439486  ...   11.197473  11.839373
# UZB                NaN        NaN        NaN  ...    1.962495   1.815115
# VCT                NaN        NaN        NaN  ...         NaN        NaN
# VEN                NaN        NaN        NaN  ...   11.509880  11.369545
# VGB                NaN        NaN        NaN  ...         NaN        NaN
# VIR                NaN        NaN        NaN  ...         NaN        NaN
# VNM                NaN        NaN        NaN  ...    4.595207   4.860665
# VUT                NaN        NaN        NaN  ...         NaN        NaN
# WLD           2.778784   2.981818   3.074811  ...    8.988864   9.099332
# WSM                NaN        NaN        NaN  ...         NaN        NaN
# XKX                NaN        NaN        NaN  ...    0.304754   0.432776
# YEM                NaN        NaN        NaN  ...    0.000000   0.000000
# ZAF                NaN        NaN        NaN  ...    2.413523   2.444968
# ZMB                NaN        NaN        NaN  ...   10.565473  10.702682
# ZWE                NaN        NaN        NaN  ...    5.474740   5.137274
#
#                    2010       2011       2012       2013       2014  \
# Country Code
# ABW                 NaN        NaN        NaN        NaN        NaN
# AFG                 NaN        NaN        NaN        NaN        NaN
# AGO            2.617235   2.726740   2.339021   2.952296   2.954635
# ALB           30.953814  16.516190  20.957911  26.309741  17.924206
# AND                 NaN        NaN        NaN        NaN        NaN
# ARB            0.514011   0.490512   0.484941   0.523548   0.496316
# ARE            0.000000   0.000000   0.000000   0.025763   0.096907
# ARG            6.050127   6.303150   6.031639   6.240375   5.878946
# ARM           35.008322  32.344467  27.007974  27.660419  27.513410
# ASM                 NaN        NaN        NaN        NaN        NaN
# ATG                 NaN        NaN        NaN        NaN        NaN
# AUS            1.475881   1.850155   1.831530   2.285736   2.553107
# AUT           10.857629  10.109595  12.878002  12.483717  12.869746
# AZE            2.558734   1.832122   1.143799   0.923792   0.783596
# BDI                 NaN        NaN        NaN        NaN        NaN
# BEL           21.036929  22.955469  20.385888  21.001693  17.953782
# BEN            0.000000   0.000000   0.000000   0.000000   0.000000
# BFA                 NaN        NaN        NaN        NaN        NaN
# BGD            0.205467   0.236907   0.201167   0.262139   0.178928
# BGR           25.368740  24.199447  25.255019  25.691031  26.933855
# BHR            0.000000   0.000000   0.000000   0.000000   0.000000
# BHS                 NaN        NaN        NaN        NaN        NaN
# BIH           10.649609   5.279956   5.423228   9.642014   6.523639
# BLR            0.014373   0.012602   0.021430   0.046033   0.041224
# BLZ                 NaN        NaN        NaN        NaN        NaN
# BMU                 NaN        NaN        NaN        NaN        NaN
# BOL            2.939634   2.993776   2.609538   2.798281   2.338001
# BRA           14.677168  15.394053  14.492366  13.198559  12.459758
# BRB                 NaN        NaN        NaN        NaN        NaN
# BRN            0.000000   0.004441   0.004491   0.005654   0.004840
# ...                 ...        ...        ...        ...        ...
# TLA           10.115569  10.057595   9.449567   9.187494   9.491416
# TLS                 NaN        NaN        NaN        NaN        NaN
# TMN            0.755187   0.783602   0.882214   1.074538   0.997148
# TON                 NaN        NaN        NaN        NaN        NaN
# TSA            2.881207   3.240553   2.993949   3.243937   3.061354
# TSS            2.526333   2.581532   2.452932   2.636127   2.805634
# TTO            0.000000   0.000000   0.000000   0.000000   0.000000
# TUN            0.423003   0.461183   0.606084   0.732721   0.893522
# TUR            6.659472   6.692657   7.176466   7.954758   7.120458
# TUV                 NaN        NaN        NaN        NaN        NaN
# TZA            1.127113   0.788239   0.660363   0.620128   0.903154
# UGA                 NaN        NaN        NaN        NaN        NaN
# UKR           18.517282  19.456627  20.085689  19.923278  22.760869
# UMC            5.110276   5.007042   5.269442   5.512911   5.884527
# URY           18.378213  12.827059  10.259235  15.603109  18.944170
# USA           11.744016  12.020836  11.899366  12.121347  12.110341
# UZB            2.158667   1.859922   1.991325   2.315794        NaN
# VCT                 NaN        NaN        NaN        NaN        NaN
# VEN            9.122743  10.708126   9.653044  10.448809        NaN
# VGB                 NaN        NaN        NaN        NaN        NaN
# VIR                 NaN        NaN        NaN        NaN        NaN
# VNM            4.029065   5.989804   7.588987   7.468364        NaN
# VUT                 NaN        NaN        NaN        NaN        NaN
# WLD            8.981862   8.626784   8.444161   8.621157   8.899332
# WSM                 NaN        NaN        NaN        NaN        NaN
# XKX            0.550763   0.366661   0.359750   0.533818   0.601531
# YEM            0.000000   0.000000   0.000000   0.000000        NaN
# ZAF            2.400945   2.668952   2.371185   2.784258   2.699056
# ZMB           10.912704  11.369337  11.648622  11.863847        NaN
# ZWE            5.272405   4.363049   4.288045   3.807027        NaN
#
#                    2015  2016  2017
# Country Code
# ABW                 NaN   NaN   NaN
# AFG                 NaN   NaN   NaN
# AGO                 NaN   NaN   NaN
# ALB                 NaN   NaN   NaN
# AND                 NaN   NaN   NaN
# ARB                 NaN   NaN   NaN
# ARE                 NaN   NaN   NaN
# ARG                 NaN   NaN   NaN
# ARM                 NaN   NaN   NaN
# ASM                 NaN   NaN   NaN
# ATG                 NaN   NaN   NaN
# AUS            2.276450   NaN   NaN
# AUT           11.867844   NaN   NaN
# AZE                 NaN   NaN   NaN
# BDI                 NaN   NaN   NaN
# BEL           14.350865   NaN   NaN
# BEN                 NaN   NaN   NaN
# BFA                 NaN   NaN   NaN
# BGD                 NaN   NaN   NaN
# BGR                 NaN   NaN   NaN
# BHR                 NaN   NaN   NaN
# BHS                 NaN   NaN   NaN
# BIH                 NaN   NaN   NaN
# BLR                 NaN   NaN   NaN
# BLZ                 NaN   NaN   NaN
# BMU                 NaN   NaN   NaN
# BOL                 NaN   NaN   NaN
# BRA                 NaN   NaN   NaN
# BRB                 NaN   NaN   NaN
# BRN                 NaN   NaN   NaN
# ...                 ...   ...   ...
# TLA            5.385024   NaN   NaN
# TLS                 NaN   NaN   NaN
# TMN                 NaN   NaN   NaN
# TON                 NaN   NaN   NaN
# TSA                 NaN   NaN   NaN
# TSS                 NaN   NaN   NaN
# TTO                 NaN   NaN   NaN
# TUN                 NaN   NaN   NaN
# TUR            9.605489   NaN   NaN
# TUV                 NaN   NaN   NaN
# TZA                 NaN   NaN   NaN
# UGA                 NaN   NaN   NaN
# UKR                 NaN   NaN   NaN
# UMC            7.028513   NaN   NaN
# URY                 NaN   NaN   NaN
# USA           12.322895   NaN   NaN
# UZB                 NaN   NaN   NaN
# VCT                 NaN   NaN   NaN
# VEN                 NaN   NaN   NaN
# VGB                 NaN   NaN   NaN
# VIR                 NaN   NaN   NaN
# VNM                 NaN   NaN   NaN
# VUT                 NaN   NaN   NaN
# WLD           14.078013   NaN   NaN
# WSM                 NaN   NaN   NaN
# XKX                 NaN   NaN   NaN
# YEM                 NaN   NaN   NaN
# ZAF                 NaN   NaN   NaN
# ZMB                 NaN   NaN   NaN
# ZWE                 NaN   NaN   NaN
#
# [264 rows x 61 columns]

# %%
print(df)
# Out:
#                                                     CountryName  \
# Country Code
# ABW                                                       Aruba
# AFG                                                 Afghanistan
# AGO                                                      Angola
# ALB                                                     Albania
# AND                                                     Andorra
# ARB                                                  Arab World
# ARE                                        United Arab Emirates
# ARG                                                   Argentina
# ARM                                                     Armenia
# ASM                                              American Samoa
# ATG                                         Antigua and Barbuda
# AUS                                                   Australia
# AUT                                                     Austria
# AZE                                                  Azerbaijan
# BDI                                                     Burundi
# BEL                                                     Belgium
# BEN                                                       Benin
# BFA                                                Burkina Faso
# BGD                                                  Bangladesh
# BGR                                                    Bulgaria
# BHR                                                     Bahrain
# BHS                                                Bahamas, The
# BIH                                      Bosnia and Herzegovina
# BLR                                                     Belarus
# BLZ                                                      Belize
# BMU                                                     Bermuda
# BOL                                                     Bolivia
# BRA                                                      Brazil
# BRB                                                    Barbados
# BRN                                           Brunei Darussalam
# ...                                                         ...
# TLA           Latin America & the Caribbean (IDA & IBRD coun...
# TLS                                                 Timor-Leste
# TMN           Middle East & North Africa (IDA & IBRD countries)
# TON                                                       Tonga
# TSA                                     South Asia (IDA & IBRD)
# TSS                   Sub-Saharan Africa (IDA & IBRD countries)
# TTO                                         Trinidad and Tobago
# TUN                                                     Tunisia
# TUR                                                      Turkey
# TUV                                                      Tuvalu
# TZA                                                    Tanzania
# UGA                                                      Uganda
# UKR                                                     Ukraine
# UMC                                         Upper middle income
# URY                                                     Uruguay
# USA                                               United States
# UZB                                                  Uzbekistan
# VCT                              St. Vincent and the Grenadines
# VEN                                               Venezuela, RB
# VGB                                      British Virgin Islands
# VIR                                       Virgin Islands (U.S.)
# VNM                                                     Vietnam
# VUT                                                     Vanuatu
# WLD                                                       World
# WSM                                                       Samoa
# XKX                                                      Kosovo
# YEM                                                 Yemen, Rep.
# ZAF                                                South Africa
# ZMB                                                      Zambia
# ZWE                                                    Zimbabwe
#
#                                                      EnergyType  \
# Country Code
# ABW           Alternative and nuclear energy (% of total ene...
# AFG           Alternative and nuclear energy (% of total ene...
# AGO           Alternative and nuclear energy (% of total ene...
# ALB           Alternative and nuclear energy (% of total ene...
# AND           Alternative and nuclear energy (% of total ene...
# ARB           Alternative and nuclear energy (% of total ene...
# ARE           Alternative and nuclear energy (% of total ene...
# ARG           Alternative and nuclear energy (% of total ene...
# ARM           Alternative and nuclear energy (% of total ene...
# ASM           Alternative and nuclear energy (% of total ene...
# ATG           Alternative and nuclear energy (% of total ene...
# AUS           Alternative and nuclear energy (% of total ene...
# AUT           Alternative and nuclear energy (% of total ene...
# AZE           Alternative and nuclear energy (% of total ene...
# BDI           Alternative and nuclear energy (% of total ene...
# BEL           Alternative and nuclear energy (% of total ene...
# BEN           Alternative and nuclear energy (% of total ene...
# BFA           Alternative and nuclear energy (% of total ene...
# BGD           Alternative and nuclear energy (% of total ene...
# BGR           Alternative and nuclear energy (% of total ene...
# BHR           Alternative and nuclear energy (% of total ene...
# BHS           Alternative and nuclear energy (% of total ene...
# BIH           Alternative and nuclear energy (% of total ene...
# BLR           Alternative and nuclear energy (% of total ene...
# BLZ           Alternative and nuclear energy (% of total ene...
# BMU           Alternative and nuclear energy (% of total ene...
# BOL           Alternative and nuclear energy (% of total ene...
# BRA           Alternative and nuclear energy (% of total ene...
# BRB           Alternative and nuclear energy (% of total ene...
# BRN           Alternative and nuclear energy (% of total ene...
# ...                                                         ...
# TLA           Alternative and nuclear energy (% of total ene...
# TLS           Alternative and nuclear energy (% of total ene...
# TMN           Alternative and nuclear energy (% of total ene...
# TON           Alternative and nuclear energy (% of total ene...
# TSA           Alternative and nuclear energy (% of total ene...
# TSS           Alternative and nuclear energy (% of total ene...
# TTO           Alternative and nuclear energy (% of total ene...
# TUN           Alternative and nuclear energy (% of total ene...
# TUR           Alternative and nuclear energy (% of total ene...
# TUV           Alternative and nuclear energy (% of total ene...
# TZA           Alternative and nuclear energy (% of total ene...
# UGA           Alternative and nuclear energy (% of total ene...
# UKR           Alternative and nuclear energy (% of total ene...
# UMC           Alternative and nuclear energy (% of total ene...
# URY           Alternative and nuclear energy (% of total ene...
# USA           Alternative and nuclear energy (% of total ene...
# UZB           Alternative and nuclear energy (% of total ene...
# VCT           Alternative and nuclear energy (% of total ene...
# VEN           Alternative and nuclear energy (% of total ene...
# VGB           Alternative and nuclear energy (% of total ene...
# VIR           Alternative and nuclear energy (% of total ene...
# VNM           Alternative and nuclear energy (% of total ene...
# VUT           Alternative and nuclear energy (% of total ene...
# WLD           Alternative and nuclear energy (% of total ene...
# WSM           Alternative and nuclear energy (% of total ene...
# XKX           Alternative and nuclear energy (% of total ene...
# YEM           Alternative and nuclear energy (% of total ene...
# ZAF           Alternative and nuclear energy (% of total ene...
# ZMB           Alternative and nuclear energy (% of total ene...
# ZWE           Alternative and nuclear energy (% of total ene...
#
#                      EnergyCode      1960      1961      1962      1963  \
# Country Code
# ABW           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# AFG           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# AGO           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# ALB           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# AND           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# ARB           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# ARE           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# ARG           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# ARM           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# ASM           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# ATG           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# AUS           EG.USE.COMM.CL.ZS  1.092123  1.216693  1.240643  1.578166
# AUT           EG.USE.COMM.CL.ZS  8.964336  8.748101  8.337474  7.468122
# AZE           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BDI           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BEL           EG.USE.COMM.CL.ZS  0.064140  0.068843  0.058123  0.087126
# BEN           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BFA           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BGD           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BGR           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BHR           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BHS           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BIH           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BLR           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BLZ           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BMU           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BOL           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BRA           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BRB           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BRN           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# ...                         ...       ...       ...       ...       ...
# TLA           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# TLS           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# TMN           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# TON           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# TSA           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# TSS           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# TTO           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# TUN           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# TUR           EG.USE.COMM.CL.ZS  0.806109  1.002690  0.815474  1.480681
# TUV           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# TZA           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# UGA           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# UKR           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# UMC           EG.USE.COMM.CL.ZS  0.806109  1.002690  0.815474  1.480681
# URY           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# USA           EG.USE.COMM.CL.ZS  1.261261  1.334758  1.430062  1.365391
# UZB           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# VCT           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# VEN           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# VGB           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# VIR           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# VNM           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# VUT           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# WLD           EG.USE.COMM.CL.ZS  2.727828  2.800560  2.764664  2.773203
# WSM           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# XKX           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# YEM           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# ZAF           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# ZMB           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# ZWE           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
#
#                   1964       1965       1966  ...        2008       2009  \
# Country Code                                  ...
# ABW                NaN        NaN        NaN  ...         NaN        NaN
# AFG                NaN        NaN        NaN  ...         NaN        NaN
# AGO                NaN        NaN        NaN  ...    2.525102   2.293878
# ALB                NaN        NaN        NaN  ...   15.898280  21.173149
# AND                NaN        NaN        NaN  ...         NaN        NaN
# ARB                NaN        NaN        NaN  ...    0.431715   0.427774
# ARE                NaN        NaN        NaN  ...    0.000000   0.000000
# ARG                NaN        NaN        NaN  ...    5.832679   6.677403
# ARM                NaN        NaN        NaN  ...   26.499591  31.568562
# ASM                NaN        NaN        NaN  ...         NaN        NaN
# ATG                NaN        NaN        NaN  ...         NaN        NaN
# AUS           1.572712   1.808353   1.470217  ...    1.152984   1.223162
# AUT           8.157981  10.023982  10.519054  ...   10.795518  12.145188
# AZE                NaN        NaN        NaN  ...    1.440744   1.664222
# BDI                NaN        NaN        NaN  ...         NaN        NaN
# BEL           0.081804   0.079324   0.093829  ...   20.503938  22.189911
# BEN                NaN        NaN        NaN  ...    0.000000   0.000000
# BFA                NaN        NaN        NaN  ...         NaN        NaN
# BGD                NaN        NaN        NaN  ...    0.305075   0.127287
# BGR                NaN        NaN        NaN  ...   22.251015  24.851118
# BHR                NaN        NaN        NaN  ...    0.000000   0.000000
# BHS                NaN        NaN        NaN  ...         NaN        NaN
# BIH                NaN        NaN        NaN  ...    7.021041   8.629780
# BLR                NaN        NaN        NaN  ...    0.012313   0.014590
# BLZ                NaN        NaN        NaN  ...         NaN        NaN
# BMU                NaN        NaN        NaN  ...         NaN        NaN
# BOL                NaN        NaN        NaN  ...    3.527998   3.367883
# BRA                NaN        NaN        NaN  ...   14.372337  15.561479
# BRB                NaN        NaN        NaN  ...         NaN        NaN
# BRN                NaN        NaN        NaN  ...    0.000000   0.000000
# ...                ...        ...        ...  ...         ...        ...
# TLA                NaN        NaN        NaN  ...    9.877785  10.066878
# TLS                NaN        NaN        NaN  ...         NaN        NaN
# TMN                NaN        NaN        NaN  ...    0.614520   0.629348
# TON                NaN        NaN        NaN  ...         NaN        NaN
# TSA                NaN        NaN        NaN  ...    2.573298   2.548723
# TSS                NaN        NaN        NaN  ...    2.381772   2.452407
# TTO                NaN        NaN        NaN  ...    0.000000   0.000000
# TUN                NaN        NaN        NaN  ...    0.062947   0.165279
# TUR           1.105815   1.409250   1.373221  ...    4.563276   5.392985
# TUV                NaN        NaN        NaN  ...         NaN        NaN
# TZA                NaN        NaN        NaN  ...    1.192854   1.157195
# UGA                NaN        NaN        NaN  ...         NaN        NaN
# UKR                NaN        NaN        NaN  ...   18.240893  19.900961
# UMC           1.105815   1.409250   1.373221  ...    4.952265   5.040086
# URY                NaN        NaN        NaN  ...    9.324447  11.040244
# USA           1.400595   1.472228   1.439486  ...   11.197473  11.839373
# UZB                NaN        NaN        NaN  ...    1.962495   1.815115
# VCT                NaN        NaN        NaN  ...         NaN        NaN
# VEN                NaN        NaN        NaN  ...   11.509880  11.369545
# VGB                NaN        NaN        NaN  ...         NaN        NaN
# VIR                NaN        NaN        NaN  ...         NaN        NaN
# VNM                NaN        NaN        NaN  ...    4.595207   4.860665
# VUT                NaN        NaN        NaN  ...         NaN        NaN
# WLD           2.778784   2.981818   3.074811  ...    8.988864   9.099332
# WSM                NaN        NaN        NaN  ...         NaN        NaN
# XKX                NaN        NaN        NaN  ...    0.304754   0.432776
# YEM                NaN        NaN        NaN  ...    0.000000   0.000000
# ZAF                NaN        NaN        NaN  ...    2.413523   2.444968
# ZMB                NaN        NaN        NaN  ...   10.565473  10.702682
# ZWE                NaN        NaN        NaN  ...    5.474740   5.137274
#
#                    2010       2011       2012       2013       2014  \
# Country Code
# ABW                 NaN        NaN        NaN        NaN        NaN
# AFG                 NaN        NaN        NaN        NaN        NaN
# AGO            2.617235   2.726740   2.339021   2.952296   2.954635
# ALB           30.953814  16.516190  20.957911  26.309741  17.924206
# AND                 NaN        NaN        NaN        NaN        NaN
# ARB            0.514011   0.490512   0.484941   0.523548   0.496316
# ARE            0.000000   0.000000   0.000000   0.025763   0.096907
# ARG            6.050127   6.303150   6.031639   6.240375   5.878946
# ARM           35.008322  32.344467  27.007974  27.660419  27.513410
# ASM                 NaN        NaN        NaN        NaN        NaN
# ATG                 NaN        NaN        NaN        NaN        NaN
# AUS            1.475881   1.850155   1.831530   2.285736   2.553107
# AUT           10.857629  10.109595  12.878002  12.483717  12.869746
# AZE            2.558734   1.832122   1.143799   0.923792   0.783596
# BDI                 NaN        NaN        NaN        NaN        NaN
# BEL           21.036929  22.955469  20.385888  21.001693  17.953782
# BEN            0.000000   0.000000   0.000000   0.000000   0.000000
# BFA                 NaN        NaN        NaN        NaN        NaN
# BGD            0.205467   0.236907   0.201167   0.262139   0.178928
# BGR           25.368740  24.199447  25.255019  25.691031  26.933855
# BHR            0.000000   0.000000   0.000000   0.000000   0.000000
# BHS                 NaN        NaN        NaN        NaN        NaN
# BIH           10.649609   5.279956   5.423228   9.642014   6.523639
# BLR            0.014373   0.012602   0.021430   0.046033   0.041224
# BLZ                 NaN        NaN        NaN        NaN        NaN
# BMU                 NaN        NaN        NaN        NaN        NaN
# BOL            2.939634   2.993776   2.609538   2.798281   2.338001
# BRA           14.677168  15.394053  14.492366  13.198559  12.459758
# BRB                 NaN        NaN        NaN        NaN        NaN
# BRN            0.000000   0.004441   0.004491   0.005654   0.004840
# ...                 ...        ...        ...        ...        ...
# TLA           10.115569  10.057595   9.449567   9.187494   9.491416
# TLS                 NaN        NaN        NaN        NaN        NaN
# TMN            0.755187   0.783602   0.882214   1.074538   0.997148
# TON                 NaN        NaN        NaN        NaN        NaN
# TSA            2.881207   3.240553   2.993949   3.243937   3.061354
# TSS            2.526333   2.581532   2.452932   2.636127   2.805634
# TTO            0.000000   0.000000   0.000000   0.000000   0.000000
# TUN            0.423003   0.461183   0.606084   0.732721   0.893522
# TUR            6.659472   6.692657   7.176466   7.954758   7.120458
# TUV                 NaN        NaN        NaN        NaN        NaN
# TZA            1.127113   0.788239   0.660363   0.620128   0.903154
# UGA                 NaN        NaN        NaN        NaN        NaN
# UKR           18.517282  19.456627  20.085689  19.923278  22.760869
# UMC            5.110276   5.007042   5.269442   5.512911   5.884527
# URY           18.378213  12.827059  10.259235  15.603109  18.944170
# USA           11.744016  12.020836  11.899366  12.121347  12.110341
# UZB            2.158667   1.859922   1.991325   2.315794        NaN
# VCT                 NaN        NaN        NaN        NaN        NaN
# VEN            9.122743  10.708126   9.653044  10.448809        NaN
# VGB                 NaN        NaN        NaN        NaN        NaN
# VIR                 NaN        NaN        NaN        NaN        NaN
# VNM            4.029065   5.989804   7.588987   7.468364        NaN
# VUT                 NaN        NaN        NaN        NaN        NaN
# WLD            8.981862   8.626784   8.444161   8.621157   8.899332
# WSM                 NaN        NaN        NaN        NaN        NaN
# XKX            0.550763   0.366661   0.359750   0.533818   0.601531
# YEM            0.000000   0.000000   0.000000   0.000000        NaN
# ZAF            2.400945   2.668952   2.371185   2.784258   2.699056
# ZMB           10.912704  11.369337  11.648622  11.863847        NaN
# ZWE            5.272405   4.363049   4.288045   3.807027        NaN
#
#                    2015  2016  2017
# Country Code
# ABW                 NaN   NaN   NaN
# AFG                 NaN   NaN   NaN
# AGO                 NaN   NaN   NaN
# ALB                 NaN   NaN   NaN
# AND                 NaN   NaN   NaN
# ARB                 NaN   NaN   NaN
# ARE                 NaN   NaN   NaN
# ARG                 NaN   NaN   NaN
# ARM                 NaN   NaN   NaN
# ASM                 NaN   NaN   NaN
# ATG                 NaN   NaN   NaN
# AUS            2.276450   NaN   NaN
# AUT           11.867844   NaN   NaN
# AZE                 NaN   NaN   NaN
# BDI                 NaN   NaN   NaN
# BEL           14.350865   NaN   NaN
# BEN                 NaN   NaN   NaN
# BFA                 NaN   NaN   NaN
# BGD                 NaN   NaN   NaN
# BGR                 NaN   NaN   NaN
# BHR                 NaN   NaN   NaN
# BHS                 NaN   NaN   NaN
# BIH                 NaN   NaN   NaN
# BLR                 NaN   NaN   NaN
# BLZ                 NaN   NaN   NaN
# BMU                 NaN   NaN   NaN
# BOL                 NaN   NaN   NaN
# BRA                 NaN   NaN   NaN
# BRB                 NaN   NaN   NaN
# BRN                 NaN   NaN   NaN
# ...                 ...   ...   ...
# TLA            5.385024   NaN   NaN
# TLS                 NaN   NaN   NaN
# TMN                 NaN   NaN   NaN
# TON                 NaN   NaN   NaN
# TSA                 NaN   NaN   NaN
# TSS                 NaN   NaN   NaN
# TTO                 NaN   NaN   NaN
# TUN                 NaN   NaN   NaN
# TUR            9.605489   NaN   NaN
# TUV                 NaN   NaN   NaN
# TZA                 NaN   NaN   NaN
# UGA                 NaN   NaN   NaN
# UKR                 NaN   NaN   NaN
# UMC            7.028513   NaN   NaN
# URY                 NaN   NaN   NaN
# USA           12.322895   NaN   NaN
# UZB                 NaN   NaN   NaN
# VCT                 NaN   NaN   NaN
# VEN                 NaN   NaN   NaN
# VGB                 NaN   NaN   NaN
# VIR                 NaN   NaN   NaN
# VNM                 NaN   NaN   NaN
# VUT                 NaN   NaN   NaN
# WLD           14.078013   NaN   NaN
# WSM                 NaN   NaN   NaN
# XKX                 NaN   NaN   NaN
# YEM                 NaN   NaN   NaN
# ZAF                 NaN   NaN   NaN
# ZMB                 NaN   NaN   NaN
# ZWE                 NaN   NaN   NaN
#
# [264 rows x 61 columns]

# %% [markdown]
# After the data was downloaded and header data (top five rows) got deleted, the data was printed in different ways to ensure that it had been properly imported.

# %%
#Remove the noncountries and print the data to ensure removal
df.drop(['ARB', 'CEB', 'CSS', 'EAP', 'EAR', 'EAS', 'ECA', 'ECS', 'EMU', 'EUU', 'FCS', 'HIC', 'HPC', 'IBD', 'IBT', 'IDA', 'IDB', 'IDX', 'INX', 'LAC', 'LCN', 'LDC', 'LIC', 'LMC', 'LMY', 'LTE', 'MEA', 'MIC', 'MNA', 'NAC', 'OED', 'OSS', 'PRE', 'PSS', 'PST', 'SAS', 'SSA', 'SSF', 'SST', 'TEA', 'TEC', 'TLA', 'TMN', 'TSA', 'TSS', 'UMC', 'WLD'], inplace=True)
print(df)
# Out:
#                                  CountryName  \
# Country Code
# ABW                                    Aruba
# AFG                              Afghanistan
# AGO                                   Angola
# ALB                                  Albania
# AND                                  Andorra
# ARE                     United Arab Emirates
# ARG                                Argentina
# ARM                                  Armenia
# ASM                           American Samoa
# ATG                      Antigua and Barbuda
# AUS                                Australia
# AUT                                  Austria
# AZE                               Azerbaijan
# BDI                                  Burundi
# BEL                                  Belgium
# BEN                                    Benin
# BFA                             Burkina Faso
# BGD                               Bangladesh
# BGR                                 Bulgaria
# BHR                                  Bahrain
# BHS                             Bahamas, The
# BIH                   Bosnia and Herzegovina
# BLR                                  Belarus
# BLZ                                   Belize
# BMU                                  Bermuda
# BOL                                  Bolivia
# BRA                                   Brazil
# BRB                                 Barbados
# BRN                        Brunei Darussalam
# BTN                                   Bhutan
# ...                                      ...
# TCA                 Turks and Caicos Islands
# TCD                                     Chad
# TGO                                     Togo
# THA                                 Thailand
# TJK                               Tajikistan
# TKM                             Turkmenistan
# TLS                              Timor-Leste
# TON                                    Tonga
# TTO                      Trinidad and Tobago
# TUN                                  Tunisia
# TUR                                   Turkey
# TUV                                   Tuvalu
# TZA                                 Tanzania
# UGA                                   Uganda
# UKR                                  Ukraine
# URY                                  Uruguay
# USA                            United States
# UZB                               Uzbekistan
# VCT           St. Vincent and the Grenadines
# VEN                            Venezuela, RB
# VGB                   British Virgin Islands
# VIR                    Virgin Islands (U.S.)
# VNM                                  Vietnam
# VUT                                  Vanuatu
# WSM                                    Samoa
# XKX                                   Kosovo
# YEM                              Yemen, Rep.
# ZAF                             South Africa
# ZMB                                   Zambia
# ZWE                                 Zimbabwe
#
#                                                      EnergyType  \
# Country Code
# ABW           Alternative and nuclear energy (% of total ene...
# AFG           Alternative and nuclear energy (% of total ene...
# AGO           Alternative and nuclear energy (% of total ene...
# ALB           Alternative and nuclear energy (% of total ene...
# AND           Alternative and nuclear energy (% of total ene...
# ARE           Alternative and nuclear energy (% of total ene...
# ARG           Alternative and nuclear energy (% of total ene...
# ARM           Alternative and nuclear energy (% of total ene...
# ASM           Alternative and nuclear energy (% of total ene...
# ATG           Alternative and nuclear energy (% of total ene...
# AUS           Alternative and nuclear energy (% of total ene...
# AUT           Alternative and nuclear energy (% of total ene...
# AZE           Alternative and nuclear energy (% of total ene...
# BDI           Alternative and nuclear energy (% of total ene...
# BEL           Alternative and nuclear energy (% of total ene...
# BEN           Alternative and nuclear energy (% of total ene...
# BFA           Alternative and nuclear energy (% of total ene...
# BGD           Alternative and nuclear energy (% of total ene...
# BGR           Alternative and nuclear energy (% of total ene...
# BHR           Alternative and nuclear energy (% of total ene...
# BHS           Alternative and nuclear energy (% of total ene...
# BIH           Alternative and nuclear energy (% of total ene...
# BLR           Alternative and nuclear energy (% of total ene...
# BLZ           Alternative and nuclear energy (% of total ene...
# BMU           Alternative and nuclear energy (% of total ene...
# BOL           Alternative and nuclear energy (% of total ene...
# BRA           Alternative and nuclear energy (% of total ene...
# BRB           Alternative and nuclear energy (% of total ene...
# BRN           Alternative and nuclear energy (% of total ene...
# BTN           Alternative and nuclear energy (% of total ene...
# ...                                                         ...
# TCA           Alternative and nuclear energy (% of total ene...
# TCD           Alternative and nuclear energy (% of total ene...
# TGO           Alternative and nuclear energy (% of total ene...
# THA           Alternative and nuclear energy (% of total ene...
# TJK           Alternative and nuclear energy (% of total ene...
# TKM           Alternative and nuclear energy (% of total ene...
# TLS           Alternative and nuclear energy (% of total ene...
# TON           Alternative and nuclear energy (% of total ene...
# TTO           Alternative and nuclear energy (% of total ene...
# TUN           Alternative and nuclear energy (% of total ene...
# TUR           Alternative and nuclear energy (% of total ene...
# TUV           Alternative and nuclear energy (% of total ene...
# TZA           Alternative and nuclear energy (% of total ene...
# UGA           Alternative and nuclear energy (% of total ene...
# UKR           Alternative and nuclear energy (% of total ene...
# URY           Alternative and nuclear energy (% of total ene...
# USA           Alternative and nuclear energy (% of total ene...
# UZB           Alternative and nuclear energy (% of total ene...
# VCT           Alternative and nuclear energy (% of total ene...
# VEN           Alternative and nuclear energy (% of total ene...
# VGB           Alternative and nuclear energy (% of total ene...
# VIR           Alternative and nuclear energy (% of total ene...
# VNM           Alternative and nuclear energy (% of total ene...
# VUT           Alternative and nuclear energy (% of total ene...
# WSM           Alternative and nuclear energy (% of total ene...
# XKX           Alternative and nuclear energy (% of total ene...
# YEM           Alternative and nuclear energy (% of total ene...
# ZAF           Alternative and nuclear energy (% of total ene...
# ZMB           Alternative and nuclear energy (% of total ene...
# ZWE           Alternative and nuclear energy (% of total ene...
#
#                      EnergyCode      1960      1961      1962      1963  \
# Country Code
# ABW           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# AFG           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# AGO           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# ALB           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# AND           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# ARE           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# ARG           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# ARM           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# ASM           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# ATG           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# AUS           EG.USE.COMM.CL.ZS  1.092123  1.216693  1.240643  1.578166
# AUT           EG.USE.COMM.CL.ZS  8.964336  8.748101  8.337474  7.468122
# AZE           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BDI           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BEL           EG.USE.COMM.CL.ZS  0.064140  0.068843  0.058123  0.087126
# BEN           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BFA           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BGD           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BGR           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BHR           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BHS           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BIH           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BLR           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BLZ           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BMU           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BOL           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BRA           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BRB           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BRN           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# BTN           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# ...                         ...       ...       ...       ...       ...
# TCA           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# TCD           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# TGO           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# THA           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# TJK           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# TKM           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# TLS           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# TON           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# TTO           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# TUN           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# TUR           EG.USE.COMM.CL.ZS  0.806109  1.002690  0.815474  1.480681
# TUV           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# TZA           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# UGA           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# UKR           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# URY           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# USA           EG.USE.COMM.CL.ZS  1.261261  1.334758  1.430062  1.365391
# UZB           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# VCT           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# VEN           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# VGB           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# VIR           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# VNM           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# VUT           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# WSM           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# XKX           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# YEM           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# ZAF           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# ZMB           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
# ZWE           EG.USE.COMM.CL.ZS       NaN       NaN       NaN       NaN
#
#                   1964       1965       1966  ...        2008       2009  \
# Country Code                                  ...
# ABW                NaN        NaN        NaN  ...         NaN        NaN
# AFG                NaN        NaN        NaN  ...         NaN        NaN
# AGO                NaN        NaN        NaN  ...    2.525102   2.293878
# ALB                NaN        NaN        NaN  ...   15.898280  21.173149
# AND                NaN        NaN        NaN  ...         NaN        NaN
# ARE                NaN        NaN        NaN  ...    0.000000   0.000000
# ARG                NaN        NaN        NaN  ...    5.832679   6.677403
# ARM                NaN        NaN        NaN  ...   26.499591  31.568562
# ASM                NaN        NaN        NaN  ...         NaN        NaN
# ATG                NaN        NaN        NaN  ...         NaN        NaN
# AUS           1.572712   1.808353   1.470217  ...    1.152984   1.223162
# AUT           8.157981  10.023982  10.519054  ...   10.795518  12.145188
# AZE                NaN        NaN        NaN  ...    1.440744   1.664222
# BDI                NaN        NaN        NaN  ...         NaN        NaN
# BEL           0.081804   0.079324   0.093829  ...   20.503938  22.189911
# BEN                NaN        NaN        NaN  ...    0.000000   0.000000
# BFA                NaN        NaN        NaN  ...         NaN        NaN
# BGD                NaN        NaN        NaN  ...    0.305075   0.127287
# BGR                NaN        NaN        NaN  ...   22.251015  24.851118
# BHR                NaN        NaN        NaN  ...    0.000000   0.000000
# BHS                NaN        NaN        NaN  ...         NaN        NaN
# BIH                NaN        NaN        NaN  ...    7.021041   8.629780
# BLR                NaN        NaN        NaN  ...    0.012313   0.014590
# BLZ                NaN        NaN        NaN  ...         NaN        NaN
# BMU                NaN        NaN        NaN  ...         NaN        NaN
# BOL                NaN        NaN        NaN  ...    3.527998   3.367883
# BRA                NaN        NaN        NaN  ...   14.372337  15.561479
# BRB                NaN        NaN        NaN  ...         NaN        NaN
# BRN                NaN        NaN        NaN  ...    0.000000   0.000000
# BTN                NaN        NaN        NaN  ...         NaN        NaN
# ...                ...        ...        ...  ...         ...        ...
# TCA                NaN        NaN        NaN  ...         NaN        NaN
# TCD                NaN        NaN        NaN  ...         NaN        NaN
# TGO                NaN        NaN        NaN  ...    0.305510   0.303630
# THA                NaN        NaN        NaN  ...    0.566908   0.572368
# TJK                NaN        NaN        NaN  ...   55.374749  64.127757
# TKM                NaN        NaN        NaN  ...    0.000000   0.000000
# TLS                NaN        NaN        NaN  ...         NaN        NaN
# TON                NaN        NaN        NaN  ...         NaN        NaN
# TTO                NaN        NaN        NaN  ...    0.000000   0.000000
# TUN                NaN        NaN        NaN  ...    0.062947   0.165279
# TUR           1.105815   1.409250   1.373221  ...    4.563276   5.392985
# TUV                NaN        NaN        NaN  ...         NaN        NaN
# TZA                NaN        NaN        NaN  ...    1.192854   1.157195
# UGA                NaN        NaN        NaN  ...         NaN        NaN
# UKR                NaN        NaN        NaN  ...   18.240893  19.900961
# URY                NaN        NaN        NaN  ...    9.324447  11.040244
# USA           1.400595   1.472228   1.439486  ...   11.197473  11.839373
# UZB                NaN        NaN        NaN  ...    1.962495   1.815115
# VCT                NaN        NaN        NaN  ...         NaN        NaN
# VEN                NaN        NaN        NaN  ...   11.509880  11.369545
# VGB                NaN        NaN        NaN  ...         NaN        NaN
# VIR                NaN        NaN        NaN  ...         NaN        NaN
# VNM                NaN        NaN        NaN  ...    4.595207   4.860665
# VUT                NaN        NaN        NaN  ...         NaN        NaN
# WSM                NaN        NaN        NaN  ...         NaN        NaN
# XKX                NaN        NaN        NaN  ...    0.304754   0.432776
# YEM                NaN        NaN        NaN  ...    0.000000   0.000000
# ZAF                NaN        NaN        NaN  ...    2.413523   2.444968
# ZMB                NaN        NaN        NaN  ...   10.565473  10.702682
# ZWE                NaN        NaN        NaN  ...    5.474740   5.137274
#
#                    2010       2011       2012       2013       2014  \
# Country Code
# ABW                 NaN        NaN        NaN        NaN        NaN
# AFG                 NaN        NaN        NaN        NaN        NaN
# AGO            2.617235   2.726740   2.339021   2.952296   2.954635
# ALB           30.953814  16.516190  20.957911  26.309741  17.924206
# AND                 NaN        NaN        NaN        NaN        NaN
# ARE            0.000000   0.000000   0.000000   0.025763   0.096907
# ARG            6.050127   6.303150   6.031639   6.240375   5.878946
# ARM           35.008322  32.344467  27.007974  27.660419  27.513410
# ASM                 NaN        NaN        NaN        NaN        NaN
# ATG                 NaN        NaN        NaN        NaN        NaN
# AUS            1.475881   1.850155   1.831530   2.285736   2.553107
# AUT           10.857629  10.109595  12.878002  12.483717  12.869746
# AZE            2.558734   1.832122   1.143799   0.923792   0.783596
# BDI                 NaN        NaN        NaN        NaN        NaN
# BEL           21.036929  22.955469  20.385888  21.001693  17.953782
# BEN            0.000000   0.000000   0.000000   0.000000   0.000000
# BFA                 NaN        NaN        NaN        NaN        NaN
# BGD            0.205467   0.236907   0.201167   0.262139   0.178928
# BGR           25.368740  24.199447  25.255019  25.691031  26.933855
# BHR            0.000000   0.000000   0.000000   0.000000   0.000000
# BHS                 NaN        NaN        NaN        NaN        NaN
# BIH           10.649609   5.279956   5.423228   9.642014   6.523639
# BLR            0.014373   0.012602   0.021430   0.046033   0.041224
# BLZ                 NaN        NaN        NaN        NaN        NaN
# BMU                 NaN        NaN        NaN        NaN        NaN
# BOL            2.939634   2.993776   2.609538   2.798281   2.338001
# BRA           14.677168  15.394053  14.492366  13.198559  12.459758
# BRB                 NaN        NaN        NaN        NaN        NaN
# BRN            0.000000   0.004441   0.004491   0.005654   0.004840
# BTN                 NaN        NaN        NaN        NaN        NaN
# ...                 ...        ...        ...        ...        ...
# TCA                 NaN        NaN        NaN        NaN        NaN
# TCD                 NaN        NaN        NaN        NaN        NaN
# TGO            0.256738   0.290950   0.245085   0.190405   0.312608
# THA            0.407010   0.604480   0.640452   0.452634   0.462050
# TJK           64.817159  63.844091  61.931932  56.439892  49.059753
# TKM            0.000000   0.000000   0.000000   0.000000   0.000000
# TLS                 NaN        NaN        NaN        NaN        NaN
# TON                 NaN        NaN        NaN        NaN        NaN
# TTO            0.000000   0.000000   0.000000   0.000000   0.000000
# TUN            0.423003   0.461183   0.606084   0.732721   0.893522
# TUR            6.659472   6.692657   7.176466   7.954758   7.120458
# TUV                 NaN        NaN        NaN        NaN        NaN
# TZA            1.127113   0.788239   0.660363   0.620128   0.903154
# UGA                 NaN        NaN        NaN        NaN        NaN
# UKR           18.517282  19.456627  20.085689  19.923278  22.760869
# URY           18.378213  12.827059  10.259235  15.603109  18.944170
# USA           11.744016  12.020836  11.899366  12.121347  12.110341
# UZB            2.158667   1.859922   1.991325   2.315794        NaN
# VCT                 NaN        NaN        NaN        NaN        NaN
# VEN            9.122743  10.708126   9.653044  10.448809        NaN
# VGB                 NaN        NaN        NaN        NaN        NaN
# VIR                 NaN        NaN        NaN        NaN        NaN
# VNM            4.029065   5.989804   7.588987   7.468364        NaN
# VUT                 NaN        NaN        NaN        NaN        NaN
# WSM                 NaN        NaN        NaN        NaN        NaN
# XKX            0.550763   0.366661   0.359750   0.533818   0.601531
# YEM            0.000000   0.000000   0.000000   0.000000        NaN
# ZAF            2.400945   2.668952   2.371185   2.784258   2.699056
# ZMB           10.912704  11.369337  11.648622  11.863847        NaN
# ZWE            5.272405   4.363049   4.288045   3.807027        NaN
#
#                    2015  2016  2017
# Country Code
# ABW                 NaN   NaN   NaN
# AFG                 NaN   NaN   NaN
# AGO                 NaN   NaN   NaN
# ALB                 NaN   NaN   NaN
# AND                 NaN   NaN   NaN
# ARE                 NaN   NaN   NaN
# ARG                 NaN   NaN   NaN
# ARM                 NaN   NaN   NaN
# ASM                 NaN   NaN   NaN
# ATG                 NaN   NaN   NaN
# AUS            2.276450   NaN   NaN
# AUT           11.867844   NaN   NaN
# AZE                 NaN   NaN   NaN
# BDI                 NaN   NaN   NaN
# BEL           14.350865   NaN   NaN
# BEN                 NaN   NaN   NaN
# BFA                 NaN   NaN   NaN
# BGD                 NaN   NaN   NaN
# BGR                 NaN   NaN   NaN
# BHR                 NaN   NaN   NaN
# BHS                 NaN   NaN   NaN
# BIH                 NaN   NaN   NaN
# BLR                 NaN   NaN   NaN
# BLZ                 NaN   NaN   NaN
# BMU                 NaN   NaN   NaN
# BOL                 NaN   NaN   NaN
# BRA                 NaN   NaN   NaN
# BRB                 NaN   NaN   NaN
# BRN                 NaN   NaN   NaN
# BTN                 NaN   NaN   NaN
# ...                 ...   ...   ...
# TCA                 NaN   NaN   NaN
# TCD                 NaN   NaN   NaN
# TGO                 NaN   NaN   NaN
# THA                 NaN   NaN   NaN
# TJK                 NaN   NaN   NaN
# TKM                 NaN   NaN   NaN
# TLS                 NaN   NaN   NaN
# TON                 NaN   NaN   NaN
# TTO                 NaN   NaN   NaN
# TUN                 NaN   NaN   NaN
# TUR            9.605489   NaN   NaN
# TUV                 NaN   NaN   NaN
# TZA                 NaN   NaN   NaN
# UGA                 NaN   NaN   NaN
# UKR                 NaN   NaN   NaN
# URY                 NaN   NaN   NaN
# USA           12.322895   NaN   NaN
# UZB                 NaN   NaN   NaN
# VCT                 NaN   NaN   NaN
# VEN                 NaN   NaN   NaN
# VGB                 NaN   NaN   NaN
# VIR                 NaN   NaN   NaN
# VNM                 NaN   NaN   NaN
# VUT                 NaN   NaN   NaN
# WSM                 NaN   NaN   NaN
# XKX                 NaN   NaN   NaN
# YEM                 NaN   NaN   NaN
# ZAF                 NaN   NaN   NaN
# ZMB                 NaN   NaN   NaN
# ZWE                 NaN   NaN   NaN
#
# [217 rows x 61 columns]

# %% [markdown]
# The codes for noncountries were manually collected from data and entered into a string and then dropped. The data was listed to ensure accuracy.

# %% [markdown]
# ## Data Modeling
# Instead of finding the minimums and maximums for 2011 and 2012, modeling was done on all of the data.

# %%
#Looking at data modeling as a dataframe
df2_describe=df.describe()
print(df2_describe)
# Out:
#             1960       1961       1962       1963       1964       1965  \
# count  25.000000  25.000000  25.000000  25.000000  25.000000  26.000000
# mean    8.056167   8.352735   8.464669   8.375343   8.419118   8.241782
# std    10.291791  10.822724  11.426978  11.246142  11.659553  11.537681
# min     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     0.727910   0.704903   0.787687   1.132621   1.105815   0.874173
# 50%     4.486547   4.124451   3.636123   4.053780   3.115228   3.237262
# 75%    12.062296  11.452543  10.476026  10.150130   9.881204   9.994442
# max    39.336067  41.459945  43.765543  42.719432  44.453340  44.978477
#
#             1966       1967       1968       1969  ...         2008  \
# count  26.000000  26.000000  26.000000  26.000000  ...   140.000000
# mean    8.429242   8.387457   8.217288   8.160536  ...     8.501047
# std    11.171744  11.537795  11.727659  11.945798  ...    12.657680
# min     0.000000   0.000000   0.011587   0.010454  ...     0.000000
# 25%     0.929034   1.001634   0.985431   0.928858  ...     0.491155
# 50%     3.874776   3.498492   3.574714   3.489257  ...     3.426398
# 75%    10.654935  10.464479  10.036529   9.825961  ...    11.179805
# max    41.215241  43.016621  44.438076  42.956023  ...    86.755199
#
#              2009        2010        2011        2012        2013        2014  \
# count  140.000000  141.000000  140.000000  141.000000  141.000000  136.000000
# mean     8.969574    9.581857    8.724409    8.707434    9.061328    9.907058
# std     13.168098   15.089074   13.250819   13.203781   13.055405   15.143998
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.533078    0.550763    0.550282    0.640452    0.732721    0.768175
# 50%      3.522515    3.687980    3.777492    3.761496    4.567673    4.132952
# 75%     11.595598   11.145943   10.606188   11.461153   11.655545   12.629040
# max     87.803505   96.709004   89.725281   89.638477   89.532280   91.984857
#
#             2015  2016  2017
# count  34.000000   0.0   0.0
# mean   17.979866   NaN   NaN
# std    18.277924   NaN   NaN
# min     0.744933   NaN   NaN
# 25%     5.410431   NaN   NaN
# 50%    12.146555   NaN   NaN
# 75%    23.530461   NaN   NaN
# max    88.400735   NaN   NaN
#
# [8 rows x 58 columns]

# %% [markdown]
# Below is the data for countries that were at or above the 75th percentile for the year 2010. Note that figures are only displayed if they are at or above the 75th percentile mark for 2010. If it is below this mark, there will be NaN.

# %%
#df.iloc['ISL']

#Isolate data at or above the 75th percentile and display
df2=df[df['2010'] > 11.145943]
df2.head(270)
# Out:
#                   CountryName  \
# Country Code
# ALB                   Albania
# ARM                   Armenia
# BEL                   Belgium
# BGR                  Bulgaria
# BRA                    Brazil
# CAN                    Canada
# CHE               Switzerland
# CRI                Costa Rica
# CZE            Czech Republic
# DEU                   Germany
# ESP                     Spain
# FIN                   Finland
# FRA                    France
# GEO                   Georgia
# HUN                   Hungary
# ISL                   Iceland
# JPN                     Japan
# KGZ           Kyrgyz Republic
# KOR               Korea, Rep.
# MNE                Montenegro
# MOZ                Mozambique
# NOR                    Norway
# NZL               New Zealand
# PHL               Philippines
# PRY                  Paraguay
# ROU                   Romania
# SLV               El Salvador
# SUR                  Suriname
# SVK           Slovak Republic
# SVN                  Slovenia
# SWE                    Sweden
# TJK                Tajikistan
# UKR                   Ukraine
# URY                   Uruguay
# USA             United States
#
#                                                      EnergyType  \
# Country Code
# ALB           Alternative and nuclear energy (% of total ene...
# ARM           Alternative and nuclear energy (% of total ene...
# BEL           Alternative and nuclear energy (% of total ene...
# BGR           Alternative and nuclear energy (% of total ene...
# BRA           Alternative and nuclear energy (% of total ene...
# CAN           Alternative and nuclear energy (% of total ene...
# CHE           Alternative and nuclear energy (% of total ene...
# CRI           Alternative and nuclear energy (% of total ene...
# CZE           Alternative and nuclear energy (% of total ene...
# DEU           Alternative and nuclear energy (% of total ene...
# ESP           Alternative and nuclear energy (% of total ene...
# FIN           Alternative and nuclear energy (% of total ene...
# FRA           Alternative and nuclear energy (% of total ene...
# GEO           Alternative and nuclear energy (% of total ene...
# HUN           Alternative and nuclear energy (% of total ene...
# ISL           Alternative and nuclear energy (% of total ene...
# JPN           Alternative and nuclear energy (% of total ene...
# KGZ           Alternative and nuclear energy (% of total ene...
# KOR           Alternative and nuclear energy (% of total ene...
# MNE           Alternative and nuclear energy (% of total ene...
# MOZ           Alternative and nuclear energy (% of total ene...
# NOR           Alternative and nuclear energy (% of total ene...
# NZL           Alternative and nuclear energy (% of total ene...
# PHL           Alternative and nuclear energy (% of total ene...
# PRY           Alternative and nuclear energy (% of total ene...
# ROU           Alternative and nuclear energy (% of total ene...
# SLV           Alternative and nuclear energy (% of total ene...
# SUR           Alternative and nuclear energy (% of total ene...
# SVK           Alternative and nuclear energy (% of total ene...
# SVN           Alternative and nuclear energy (% of total ene...
# SWE           Alternative and nuclear energy (% of total ene...
# TJK           Alternative and nuclear energy (% of total ene...
# UKR           Alternative and nuclear energy (% of total ene...
# URY           Alternative and nuclear energy (% of total ene...
# USA           Alternative and nuclear energy (% of total ene...
#
#                      EnergyCode       1960       1961       1962       1963  \
# Country Code
# ALB           EG.USE.COMM.CL.ZS        NaN        NaN        NaN        NaN
# ARM           EG.USE.COMM.CL.ZS        NaN        NaN        NaN        NaN
# BEL           EG.USE.COMM.CL.ZS   0.064140   0.068843   0.058123   0.087126
# BGR           EG.USE.COMM.CL.ZS        NaN        NaN        NaN        NaN
# BRA           EG.USE.COMM.CL.ZS        NaN        NaN        NaN        NaN
# CAN           EG.USE.COMM.CL.ZS  12.062296  11.452543  10.894714  10.150130
# CHE           EG.USE.COMM.CL.ZS  23.681824  23.501717  20.818427  18.194603
# CRI           EG.USE.COMM.CL.ZS        NaN        NaN        NaN        NaN
# CZE           EG.USE.COMM.CL.ZS        NaN        NaN        NaN        NaN
# DEU           EG.USE.COMM.CL.ZS   0.727910   0.704903   0.640190   0.573368
# ESP           EG.USE.COMM.CL.ZS   8.314033   8.017884   7.361913   9.316138
# FIN           EG.USE.COMM.CL.ZS   4.656269   6.865687   7.920896   6.421880
# FRA           EG.USE.COMM.CL.ZS   4.486547   4.124451   3.636123   4.053780
# GEO           EG.USE.COMM.CL.ZS        NaN        NaN        NaN        NaN
# HUN           EG.USE.COMM.CL.ZS        NaN        NaN        NaN        NaN
# ISL           EG.USE.COMM.CL.ZS  27.872272  30.243309  30.782643  30.289981
# JPN           EG.USE.COMM.CL.ZS   6.223620   6.396759   5.578866   5.390957
# KGZ           EG.USE.COMM.CL.ZS        NaN        NaN        NaN        NaN
# KOR           EG.USE.COMM.CL.ZS        NaN        NaN        NaN        NaN
# MNE           EG.USE.COMM.CL.ZS        NaN        NaN        NaN        NaN
# MOZ           EG.USE.COMM.CL.ZS        NaN        NaN        NaN        NaN
# NOR           EG.USE.COMM.CL.ZS  39.336067  41.459945  43.765543  42.719432
# NZL           EG.USE.COMM.CL.ZS  20.720532  22.672411  28.963790  31.095355
# PHL           EG.USE.COMM.CL.ZS        NaN        NaN        NaN        NaN
# PRY           EG.USE.COMM.CL.ZS        NaN        NaN        NaN        NaN
# ROU           EG.USE.COMM.CL.ZS        NaN        NaN        NaN        NaN
# SLV           EG.USE.COMM.CL.ZS        NaN        NaN        NaN        NaN
# SUR           EG.USE.COMM.CL.ZS        NaN        NaN        NaN        NaN
# SVK           EG.USE.COMM.CL.ZS        NaN        NaN        NaN        NaN
# SVN           EG.USE.COMM.CL.ZS        NaN        NaN        NaN        NaN
# SWE           EG.USE.COMM.CL.ZS  13.211098  15.250047  15.273287  13.902755
# TJK           EG.USE.COMM.CL.ZS        NaN        NaN        NaN        NaN
# UKR           EG.USE.COMM.CL.ZS        NaN        NaN        NaN        NaN
# URY           EG.USE.COMM.CL.ZS        NaN        NaN        NaN        NaN
# USA           EG.USE.COMM.CL.ZS   1.261261   1.334758   1.430062   1.365391
#
#                    1964       1965       1966  ...        2008       2009  \
# Country Code                                   ...
# ALB                 NaN        NaN        NaN  ...   15.898280  21.173149
# ARM                 NaN        NaN        NaN  ...   26.499591  31.568562
# BEL            0.081804   0.079324   0.093829  ...   20.503938  22.189911
# BGR                 NaN        NaN        NaN  ...   22.251015  24.851118
# BRA                 NaN        NaN        NaN  ...   14.372337  15.561479
# CAN           10.418460  10.046360  10.700228  ...   21.219619  21.264135
# CHE           18.003202  18.664015  20.440252  ...   39.503175  39.195991
# CRI                 NaN        NaN        NaN  ...   32.840761  35.099840
# CZE                 NaN        NaN        NaN  ...   15.884379  17.470344
# DEU            0.555567   0.695814   0.780972  ...   13.509257  13.276624
# ESP            8.216078   7.413306   9.182350  ...   14.791688  15.660868
# FIN            5.884521   6.104140   6.357658  ...   21.103354  21.655089
# FRA            3.115228   4.096395   4.592995  ...   45.631498  44.478029
# GEO                 NaN        NaN        NaN  ...   20.965673  22.013049
# HUN                 NaN   0.044544   0.058352  ...   15.151764  16.834450
# ISL           31.832583  30.408899  31.238779  ...   86.755199  87.803505
# JPN            4.796330   4.858976   4.736063  ...   15.664633  17.673952
# KGZ                 NaN        NaN        NaN  ...   27.561180  30.461892
# KOR                 NaN        NaN        NaN  ...   17.485643  16.975606
# MNE                 NaN        NaN        NaN  ...   10.373611  17.497311
# MOZ                 NaN        NaN        NaN  ...   13.984423  15.124689
# NOR           44.453340  44.978477  41.215241  ...   37.381738  34.680131
# NZL           31.416586  32.335360  32.372960  ...   26.553796  29.787183
# PHL                 NaN        NaN        NaN  ...   25.109499  25.461006
# PRY                 NaN        NaN        NaN  ...         NaN        NaN
# ROU                 NaN        NaN        NaN  ...   11.182178  12.680552
# SLV                 NaN        NaN        NaN  ...   32.931005  34.173194
# SUR                 NaN        NaN        NaN  ...   19.238220  19.057950
# SVK                 NaN        NaN        NaN  ...   25.968362  24.551513
# SVN                 NaN        NaN        NaN  ...   25.537197  26.865958
# SWE           14.761907  15.034808  13.818964  ...   45.908605  42.910298
# TJK                 NaN        NaN        NaN  ...   55.374749  64.127757
# UKR                 NaN        NaN        NaN  ...   18.240893  19.900961
# URY                 NaN        NaN        NaN  ...    9.324447  11.040244
# USA            1.400595   1.472228   1.439486  ...   11.197473  11.839373
#
#                    2010       2011       2012       2013       2014  \
# Country Code
# ALB           30.953814  16.516190  20.957911  26.309741  17.924206
# ARM           35.008322  32.344467  27.007974  27.660419  27.513410
# BEL           21.036929  22.955469  20.385888  21.001693  17.953782
# BGR           25.368740  24.199447  25.255019  25.691031  26.933855
# BRA           14.677168  15.394053  14.492366  13.198559  12.459758
# CAN           20.631220  21.216998  21.776408  22.954555  22.539917
# CHE           39.325956  39.768040  40.413537  39.419558  43.566009
# CRI           35.179248  36.031454  38.659031  37.023244  36.752673
# CZE           17.239017  18.212196  19.579462  20.269476  20.208140
# DEU           13.234924  11.646060  11.251537  11.071707  11.709405
# ESP           19.295804  18.082211  19.493105  21.846239  22.609950
# FIN           19.330299  20.313549  22.028380  22.017253  21.790571
# FRA           45.273487  47.991668  46.779681  46.885254  50.074409
# GEO           27.268805  19.446688  17.058689  18.647277  16.711500
# HUN           16.682173  17.178575  18.437284  18.883099  19.057686
# ISL           88.454645  89.725281  89.638477  89.532280  88.995526
# JPN           17.204222   8.110850   3.207093   2.979747   2.791515
# KGZ           34.695089  36.732075  29.498309  28.526969  30.131806
# KOR           15.701631  15.727862  15.111961  14.016657  15.489597
# MNE           20.113058   9.197600  11.956779  21.934329  15.752299
# MOZ           14.373696  13.953373  12.340516  11.443577  11.954740
# NOR           29.836621  37.362362  41.574230  34.313380  41.318400
# NZL           32.410050  33.601836  31.487162  33.195138  34.508007
# PHL           22.804188  23.086743  22.425131  20.369846  20.266950
# PRY           96.709004        NaN        NaN        NaN  91.984857
# ROU           13.669719  12.488046  12.242172  14.940561  16.918493
# SLV           35.063733  34.762224  34.991913  37.480840  36.575875
# SUR           14.507058  14.561000  13.755817  16.269988  16.935561
# SVK           24.254790  25.590239  26.949780  27.306381  28.270919
# SVN           25.911388  26.898772  25.964171  26.820825  33.705886
# SWE           41.436654  44.156492  48.055074  47.474946  48.535629
# TJK           64.817159  63.844091  61.931932  56.439892  49.059753
# UKR           18.517282  19.456627  20.085689  19.923278  22.760869
# URY           18.378213  12.827059  10.259235  15.603109  18.944170
# USA           11.744016  12.020836  11.899366  12.121347  12.110341
#
#                    2015  2016  2017
# Country Code
# ALB                 NaN   NaN   NaN
# ARM                 NaN   NaN   NaN
# BEL           14.350865   NaN   NaN
# BGR                 NaN   NaN   NaN
# BRA                 NaN   NaN   NaN
# CAN           22.926061   NaN   NaN
# CHE           40.160451   NaN   NaN
# CRI                 NaN   NaN   NaN
# CZE           18.046690   NaN   NaN
# DEU           11.970216   NaN   NaN
# ESP           20.719451   NaN   NaN
# FIN           23.731927   NaN   NaN
# FRA           49.467323   NaN   NaN
# GEO                 NaN   NaN   NaN
# HUN           18.338717   NaN   NaN
# ISL           88.400735   NaN   NaN
# JPN            3.658929   NaN   NaN
# KGZ                 NaN   NaN   NaN
# KOR           15.839186   NaN   NaN
# MNE                 NaN   NaN   NaN
# MOZ                 NaN   NaN   NaN
# NOR           40.117282   NaN   NaN
# NZL           34.967912   NaN   NaN
# PHL                 NaN   NaN   NaN
# PRY                 NaN   NaN   NaN
# ROU                 NaN   NaN   NaN
# SLV                 NaN   NaN   NaN
# SUR                 NaN   NaN   NaN
# SVK           27.129850   NaN   NaN
# SVN           28.477674   NaN   NaN
# SWE           45.018266   NaN   NaN
# TJK                 NaN   NaN   NaN
# UKR                 NaN   NaN   NaN
# URY                 NaN   NaN   NaN
# USA           12.322895   NaN   NaN
#
# [35 rows x 61 columns]

# %% [markdown]
# Below is the list of all of the countries that were at or above 75th percentile for the year 2010. If they also had data for any year that was below that figure, it is seen as NaN.

# %%
print(df2.index, df2.CountryName)
# Out:
# Index(['ALB', 'ARM', 'BEL', 'BGR', 'BRA', 'CAN', 'CHE', 'CRI', 'CZE', 'DEU',
#        'ESP', 'FIN', 'FRA', 'GEO', 'HUN', 'ISL', 'JPN', 'KGZ', 'KOR', 'MNE',
#        'MOZ', 'NOR', 'NZL', 'PHL', 'PRY', 'ROU', 'SLV', 'SUR', 'SVK', 'SVN',
#        'SWE', 'TJK', 'UKR', 'URY', 'USA'],
#       dtype='object', name='Country Code') Country Code
# ALB            Albania
# ARM            Armenia
# BEL            Belgium
# BGR           Bulgaria
# BRA             Brazil
# CAN             Canada
# CHE        Switzerland
# CRI         Costa Rica
# CZE     Czech Republic
# DEU            Germany
# ESP              Spain
# FIN            Finland
# FRA             France
# GEO            Georgia
# HUN            Hungary
# ISL            Iceland
# JPN              Japan
# KGZ    Kyrgyz Republic
# KOR        Korea, Rep.
# MNE         Montenegro
# MOZ         Mozambique
# NOR             Norway
# NZL        New Zealand
# PHL        Philippines
# PRY           Paraguay
# ROU            Romania
# SLV        El Salvador
# SUR           Suriname
# SVK    Slovak Republic
# SVN           Slovenia
# SWE             Sweden
# TJK         Tajikistan
# UKR            Ukraine
# URY            Uruguay
# USA      United States
# Name: CountryName, dtype: object

# %% [markdown]
# ## Analysis and Conclusion

# %% [markdown]
# All of the countries that have what might be called unusually high energy percentages were found. The use of the 2010 75th percentile should ensure that these countries' energy percentages are more or less current and do not reflect a long ago flash in the pan. One area for further exploration are the factors that go into how much a nation invests in nuclear and alternative energy. If a country has strong oil reserves, it might not seem beneficial to use other sources of energy. Additonally, some countries are well positioned to use these other sources. For example Iceland, with the high nuclear and alternative energy percentages at over 89%, has a population of only a few hundred thousand and about 90% of its households use geothermal energy according to the UN (https://unchronicle.un.org/article/iceland-s-sustainable-energy-story-model-world); it would be interesting to see this data broken down by the specific source of energy. The average of just under nine percent is interesting, but becuase the amount of energy produced is not taken into account, the two figures do not completely address questions of widespread usage of nuclear and alternative energy sources. This is becuase of the nature of climate change. If a quarter of a superpower's energy comes from nuclear or alternative sources but the other 75% still comes from fossil fuels, more environmental damage is done than a country that has a percentage of ten but produces so much less energy it doesn't matter. On the other hand, this data indicates how much is being invested into cleaner sources of energy, and that creates immidiate posotive effects in terms of climate change. One more area for further exploration are the factors that contribute to the slight increases and decreases (not to mention the dramatic ones) from year to year. For example the average percentage increased slightly from 2011 to 2012. What event or events caused this? Additonally, it would be interesting to see how small countries such as Tajikstan and Suriname are able to produce so much energy using alternative sources. What about their situation allows them to do this? This data serves as a good start to answer the deeper questions raised, but its usefulness diminishes somewhat after that.

# %% [markdown]
# ## Aknowledgements
# Ms. Sconyers provided me with all of the code present in both data preparation and modeling. A thanks to the International Energy Agency, the Organization for Economic Cooperation and Development, and the Wolrd Bank for collecting and publishing this data (this data was published by the World Bank but it is owned by the IEA and OECD). Also, the United Nations provided information on Iceland's energy production that assisted in analysis.
